# %%
import torch
from torch import nn

import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets, transforms

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
device = "mps" if torch.backends.mps.is_available() \
    else "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %% [markdown]
# # Prepare Data

# %% [markdown]
# ### Normal Data

# %%
Normal_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0],std=[1])
])

# %%
# Setup training data
Train_Normal_data = datasets.CIFAR10(
    root="/kaggle/working", # where to download data to?
    train=True, # get training data
    download=True, # download data if it doesn't exist on disk
    transform=Normal_transform, # images come as PIL format, we want to turn into Torch tensors
)
Test_Normal_data = datasets.CIFAR10(
    root="/kaggle/working", # where to download data to?
    train=False, # get training data
    download=True, # download data if it doesn't exist on disk
    transform=Normal_transform, # images come as PIL format, we want to turn into Torch tensors
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(f"Length of dataset: {len(Train_Normal_data)}") 
print(f"Length of dataset: {len(Test_Normal_data)}") 
print(f"Shape of one sample: {Train_Normal_data[0][0].shape}")
plt.imshow(Train_Normal_data[0][0].permute(1,2,0))
# Out:
# Length of dataset: 50000
# Length of dataset: 10000
# Shape of one sample: torch.Size([3, 32, 32])

# %% [markdown]
# ### Super_Resolution Data

# %%
Downscale_transform = transforms.Compose([
    transforms.Resize((16,16)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0],std=[1])
])

# %%
Train_Downscaled_data = datasets.CIFAR10(
    root="/kaggle/working", # where to download data to?
    train=True, # get training data
    download=False, # download data if it doesn't exist on disk
    transform=Downscale_transform, # images come as PIL format, we want to turn into Torch tensors
)
Test_Downscaled_data = datasets.CIFAR10(
    root="/kaggle/working", # where to download data to?
    train=False, # get training data
    download=False, # download data if it doesn't exist on disk
    transform=Downscale_transform, # images come as PIL format, we want to turn into Torch tensors
)

# %%
print(f"Length of dataset: {len(Train_Downscaled_data)}") 
print(f"Length of dataset: {len(Test_Downscaled_data)}") 
print(f"Shape of one sample: {Train_Downscaled_data[0][0].shape}")
plt.imshow(Train_Downscaled_data[0][0].permute(1,2,0))
# Out:
# Length of dataset: 50000
# Length of dataset: 10000
# Shape of one sample: torch.Size([3, 16, 16])

# %% [markdown]
# ### Denoise Data

# %%
class Noisify(object):
    def __call__(self, data):
        # Assuming data is a numpy array
        return (data + np.random.normal(loc=0.2, scale=0.3, size=data.shape)).float()
    
Noise_transform = transforms.Compose([
    transforms.ToTensor(),
    Noisify(),  # Apply the custom Noisify transformation
    transforms.Normalize(mean=[0], std=[1]),  # Normalize the tensor
    
])

# %%
Train_Noisy_data = datasets.CIFAR10(
    root="/kaggle/working", # where to download data to?
    train=True, # get training data
    download=False, # download data if it doesn't exist on disk
    transform=Noise_transform, # images come as PIL format, we want to turn into Torch tensors
)
Test_Noisy_data = datasets.CIFAR10(
    root="/kaggle/working", # where to download data to?
    train=False, # get training data
    download=False, # download data if it doesn't exist on disk
    transform=Noise_transform, # images come as PIL format, we want to turn into Torch tensors
)

# %%
print(f"Length of dataset: {len(Train_Noisy_data)}") 
print(f"Length of dataset: {len(Test_Noisy_data)}") 
print(f"Shape of one sample: {Train_Noisy_data[0][0].shape}")
plt.imshow(Train_Noisy_data[0][0].permute(1,2,0))
# Out:
# Length of dataset: 50000
# Length of dataset: 10000
# Shape of one sample: torch.Size([3, 32, 32])

# %% [markdown]
# # DeNoiser

# %% [markdown]
# ### Make Dataset

# %%
class CombinedDataset(Dataset):
    def __init__(self, dataset1, dataset2):
        self.dataset1 = dataset1
        self.dataset2 = dataset2

        # Ensure the lengths of both datasets are the same
        assert len(dataset1) == len(dataset2)

    def __len__(self):
        return len(self.dataset1)

    def __getitem__(self, index):
        data1 = self.dataset1[index][0]
        data2 = self.dataset2[index][0]

        return (data1, data2)

# %%
train_data = CombinedDataset(Train_Noisy_data, Train_Normal_data)
test_data = CombinedDataset(Test_Noisy_data, Test_Normal_data)

# %%
print(f"Length of dataset: {len(train_data)}") 
print(f"Length of dataset: {len(test_data)}") 
print(f"Shape of one sample: {train_data[0][0].shape}, {train_data[0][1].shape}")
fix, ax = plt.subplots(1,2)
ax[0].imshow(train_data[0][0].permute(1,2,0))
ax[1].imshow(train_data[0][1].permute(1,2,0))
# Out:
# Length of dataset: 50000
# Length of dataset: 10000
# Shape of one sample: torch.Size([3, 32, 32]), torch.Size([3, 32, 32])

# %% [markdown]
# ### Prepare dataloader

# %%
# Setup the batch size hyperparameter
BATCH_SIZE = 128

# Turn datasets into iterables (batches)
train_dataloader = DataLoader(train_data, # dataset to turn into iterable
    batch_size=BATCH_SIZE, # how many samples per batch? 
    shuffle=True # shuffle data every epoch?
)

test_dataloader = DataLoader(test_data,
    batch_size=BATCH_SIZE,
    shuffle=False # don't necessarily have to shuffle the testing data
)

# Let's check out what we've created
print(f"Dataloaders: {train_dataloader, test_dataloader}") 
print(f"Length of training dataset: {len(train_dataloader.dataset)}")
print(f"Length of train dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of test dataset: {len(test_dataloader.dataset)}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}")
# Out:
# Dataloaders: (<torch.utils.data.dataloader.DataLoader object at 0x7dd861a7c580>, <torch.utils.data.dataloader.DataLoader object at 0x7dd85aaa3340>)
# Length of training dataset: 50000
# Length of train dataloader: 391 batches of 128
# Length of test dataset: 10000
# Length of test dataloader: 79 batches of 128

# %%
batch = next(iter(train_dataloader))
batch[0].shape, batch[1].shape
# Out:
# (torch.Size([128, 3, 32, 32]), torch.Size([128, 3, 32, 32]))

# %% [markdown]
# ### Model architecture

# %%
class DeNoiser(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels=3, 
                      out_channels=16, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(), 
            nn.InstanceNorm2d(16),
            
            nn.Conv2d(in_channels=16, 
                      out_channels=16, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(), 
            nn.InstanceNorm2d(16),
            
            
            nn.MaxPool2d(kernel_size = (2,2)),
            
            
            nn.Conv2d(in_channels=16, 
                      out_channels=16, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),
            nn.InstanceNorm2d(16),
            
            nn.Conv2d(in_channels=16, 
                      out_channels=16, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),
            nn.InstanceNorm2d(16),
            
            
            nn.MaxPool2d(kernel_size = (2,2)),

            
            nn.Conv2d(in_channels=16,
                      out_channels=8, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),
            nn.InstanceNorm2d(8),
            
            nn.Conv2d(in_channels=8,
                      out_channels=8, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),
            nn.InstanceNorm2d(8),
            
            
            nn.MaxPool2d(kernel_size = (2,2)),
        )
        
        self.decoder = nn.Sequential(
             nn.Conv2d(in_channels=8,
                      out_channels=8, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),  
            nn.InstanceNorm2d(8),
            
            nn.Conv2d(in_channels=8,
                      out_channels=8, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),  
            nn.InstanceNorm2d(8),
            
            nn.UpsamplingBilinear2d(scale_factor = 2),
            
            nn.Conv2d(in_channels=8,
                      out_channels=8, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),  
            nn.InstanceNorm2d(8),
            
            nn.Conv2d(in_channels=8,
                      out_channels=8, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),  
            nn.InstanceNorm2d(8),
            
            
            nn.UpsamplingBilinear2d(scale_factor = 2),
            
            
            nn.Conv2d(in_channels=8,
                      out_channels=16, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),  
            nn.InstanceNorm2d(16),
            
            nn.Conv2d(in_channels=16,
                      out_channels=16, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),  
            nn.InstanceNorm2d(16),
            
            
            nn.UpsamplingBilinear2d(scale_factor = 2),
             
            nn.Conv2d(in_channels=16,
                      out_channels=16, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),  
            nn.InstanceNorm2d(16),
            
            nn.Conv2d(in_channels=16,
                      out_channels=3, 
                      kernel_size=(3,3), 
                      padding='same')
        )
    
    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
model_0 = DeNoiser()
with torch.no_grad():
    print(model_0(batch[0]).shape)

model_0
# Out:
# torch.Size([128, 3, 32, 32])
# DeNoiser(
#   (encoder): Sequential(
#     (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (4): ReLU()
#     (5): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (6): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (8): ReLU()
#     (9): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (10): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (11): ReLU()
#     (12): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (13): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (15): ReLU()
#     (16): InstanceNorm2d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (17): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (18): ReLU()
#     (19): InstanceNorm2d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (20): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): InstanceNorm2d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (3): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (4): ReLU()
#     (5): InstanceNorm2d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (6): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#     (7): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (8): ReLU()
#     (9): InstanceNorm2d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (10): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (11): ReLU()
#     (12): InstanceNorm2d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (13): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#     (14): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (15): ReLU()
#     (16): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (17): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (18): ReLU()
#     (19): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (20): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#     (21): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (22): ReLU()
#     (23): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (24): Conv2d(16, 3, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   )
# )

# %% [markdown]
# ### Train model

# %%
def train_step(model: torch.nn.Module,
               data_loader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               device: torch.device = 'cpu'):
    
    if device != 'cpu':
        model.to(device)
    
    train_loss = 0
    model.train()
    for batch, (X, y) in enumerate(data_loader):
        # Send data to GPU
        
        if device != 'cpu':
            X, y = X.to(device), y.to(device)

        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate loss
        loss = loss_fn(y_pred, y)
        train_loss += loss
        
        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

    train_loss /= len(data_loader)
    
    return train_loss

def test_step(model: torch.nn.Module,
              data_loader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module,
              device: torch.device = 'cpu'):
    
    if device != 'cpu':
        model.to(device)

    test_loss = 0
    model.eval() # put model in eval mode
    # Turn on inference context manager
    with torch.inference_mode(): 
        for X, y in data_loader:
            # Send data to GPU
            if device != 'cpu':
                X, y = X.to(device), y.to(device)
            
            # 1. Forward pass
            y_pred = model(X)
            
            # 2. Calculate loss
            test_loss += loss_fn(y_pred, y)
        
        test_loss /= len(data_loader)
    
    return test_loss

# %%
from typing import Dict, List, Tuple
from tqdm.auto import tqdm


def train(model: torch.nn.Module, 
          train_dataloader: torch.utils.data.DataLoader, 
          test_dataloader: torch.utils.data.DataLoader, 
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module,
          epochs: int,
          device: torch.device = 'cpu') -> Dict[str, List]:
    
    # Create empty results dictionary
    results = {
        "Training_Loss": [],
        "Test_Loss": []
    }

    # Loop through training and testing steps for a number of epochs
    for epoch in tqdm(range(epochs)):
            Training_Loss = train_step(
                data_loader=train_dataloader, 
                model=model, 
                loss_fn=loss_fn,
                optimizer=optimizer,
                device=device
            )
            Test_Loss = test_step(
                data_loader=test_dataloader,
                model=model,
                loss_fn=loss_fn,
                device=device
            )
            # Print out what's happening
            print(
                f"Epoch: {epoch} | "
                f"Training_Loss: {Training_Loss:.4f} | "
                f"Test_Loss: {Test_Loss:.4f} | "
            )

            # Update results dictionary
            results["Training_Loss"].append(Training_Loss.item())
            results["Test_Loss"].append(Test_Loss.item())

  # Return the filled results at the end of the epochs
    return results

# %%
# Setup loss function and optimizer
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(params=model_0.parameters(), lr=0.01)

# %%
# Setup the num_epochs hyperparameter
NUM_EPOCHS = 50

results = train(model=model_0,
                train_dataloader=train_dataloader,
                test_dataloader=test_dataloader,
                optimizer=optimizer,
                loss_fn=loss_fn,
                epochs=NUM_EPOCHS,
                device=device)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch: 0 | Training_Loss: 0.0571 | Test_Loss: 0.0321 |
# Epoch: 1 | Training_Loss: 0.0272 | Test_Loss: 0.0235 |
# Epoch: 2 | Training_Loss: 0.0230 | Test_Loss: 0.0219 |
# Epoch: 3 | Training_Loss: 0.0217 | Test_Loss: 0.0208 |
# Epoch: 4 | Training_Loss: 0.0210 | Test_Loss: 0.0208 |
# Epoch: 5 | Training_Loss: 0.0204 | Test_Loss: 0.0196 |
# Epoch: 6 | Training_Loss: 0.0200 | Test_Loss: 0.0189 |
# Epoch: 7 | Training_Loss: 0.0196 | Test_Loss: 0.0201 |
# Epoch: 8 | Training_Loss: 0.0193 | Test_Loss: 0.0235 |
# Epoch: 9 | Training_Loss: 0.0190 | Test_Loss: 0.0188 |
# Epoch: 10 | Training_Loss: 0.0187 | Test_Loss: 0.0177 |
# Epoch: 11 | Training_Loss: 0.0185 | Test_Loss: 0.0176 |
# Epoch: 12 | Training_Loss: 0.0183 | Test_Loss: 0.0171 |
# Epoch: 13 | Training_Loss: 0.0182 | Test_Loss: 0.0184 |
# Epoch: 14 | Training_Loss: 0.0180 | Test_Loss: 0.0171 |
# Epoch: 15 | Training_Loss: 0.0178 | Test_Loss: 0.0176 |
# Epoch: 16 | Training_Loss: 0.0179 | Test_Loss: 0.0184 |
# Epoch: 17 | Training_Loss: 0.0175 | Test_Loss: 0.0180 |
# Epoch: 18 | Training_Loss: 0.0175 | Test_Loss: 0.0168 |
# Epoch: 19 | Training_Loss: 0.0174 | Test_Loss: 0.0174 |
# Epoch: 20 | Training_Loss: 0.0174 | Test_Loss: 0.0182 |
# Epoch: 21 | Training_Loss: 0.0172 | Test_Loss: 0.0197 |
# Epoch: 22 | Training_Loss: 0.0172 | Test_Loss: 0.0201 |
# Epoch: 23 | Training_Loss: 0.0171 | Test_Loss: 0.0174 |
# Epoch: 24 | Training_Loss: 0.0170 | Test_Loss: 0.0162 |
# Epoch: 25 | Training_Loss: 0.0169 | Test_Loss: 0.0169 |
# Epoch: 26 | Training_Loss: 0.0169 | Test_Loss: 0.0162 |
# Epoch: 27 | Training_Loss: 0.0168 | Test_Loss: 0.0174 |
# Epoch: 28 | Training_Loss: 0.0168 | Test_Loss: 0.0166 |
# Epoch: 29 | Training_Loss: 0.0166 | Test_Loss: 0.0179 |
# Epoch: 30 | Training_Loss: 0.0166 | Test_Loss: 0.0162 |
# Epoch: 31 | Training_Loss: 0.0166 | Test_Loss: 0.0164 |
# Epoch: 32 | Training_Loss: 0.0165 | Test_Loss: 0.0162 |
# Epoch: 33 | Training_Loss: 0.0165 | Test_Loss: 0.0159 |
# Epoch: 34 | Training_Loss: 0.0164 | Test_Loss: 0.0164 |
# Epoch: 35 | Training_Loss: 0.0163 | Test_Loss: 0.0165 |
# Epoch: 36 | Training_Loss: 0.0163 | Test_Loss: 0.0170 |
# Epoch: 37 | Training_Loss: 0.0163 | Test_Loss: 0.0159 |
# Epoch: 38 | Training_Loss: 0.0163 | Test_Loss: 0.0156 |
# Epoch: 39 | Training_Loss: 0.0162 | Test_Loss: 0.0163 |
# Epoch: 40 | Training_Loss: 0.0162 | Test_Loss: 0.0159 |
# Epoch: 41 | Training_Loss: 0.0162 | Test_Loss: 0.0160 |
# Epoch: 42 | Training_Loss: 0.0161 | Test_Loss: 0.0163 |
# Epoch: 43 | Training_Loss: 0.0161 | Test_Loss: 0.0157 |
# Epoch: 44 | Training_Loss: 0.0160 | Test_Loss: 0.0161 |
# Epoch: 45 | Training_Loss: 0.0160 | Test_Loss: 0.0154 |
# Epoch: 46 | Training_Loss: 0.0160 | Test_Loss: 0.0160 |
# Epoch: 47 | Training_Loss: 0.0160 | Test_Loss: 0.0186 |
# Epoch: 48 | Training_Loss: 0.0160 | Test_Loss: 0.0160 |
# Epoch: 49 | Training_Loss: 0.0159 | Test_Loss: 0.0158 |

# %% [markdown]
# ### Plot training results

# %%
def plot_results(Training_Loss, Test_Loss):
    plt.figure(figsize=(10,5))
    
    plt.plot(Training_Loss, color="blue", label="Training Loss")
    plt.plot(Test_Loss, color="green", label="Test Loss")
    plt.title("Training and Test Loss curves")
    plt.xlabel("Epoch")
    plt.ylabel("Loss value")
    plt.legend()

    plt.show()
    
plot_results(results["Training_Loss"], results["Test_Loss"])

# %% [markdown]
# ### Test

# %%
random_indices = torch.randint(0,10_000, size = [7])
random_indices
# Out:
# tensor([ 637, 6837, 9026,  160, 8186, 9999, 3652])

# %%
fig, ax = plt.subplots(nrows=7, ncols=3, figsize = (10,10))  
fig.set_facecolor('white')


for i in range(7):
    ax[i][0].imshow(test_data[random_indices[i]][0].permute(1,2,0))
    ax[i][0].set_title('Noise data')
    
    ax[i][1].imshow(test_data[random_indices[i]][1].permute(1,2,0))
    ax[i][1].set_title('Noise-free data')
    
    with torch.no_grad():
        prediction = model_0(test_data[random_indices[i]][0].unsqueeze(0).to(device))
    prediction_np = prediction.cpu().numpy().squeeze(0).transpose(1, 2, 0)
    ax[i][2].imshow(prediction_np)
    ax[i][2].set_title('Model_prediction')
    
plt.tight_layout()

# %% [markdown]
# # Super-Resolution

# %% [markdown]
# ### Make Dataset

# %%
train_data = CombinedDataset(Train_Downscaled_data, Train_Normal_data)
test_data = CombinedDataset(Test_Downscaled_data, Test_Normal_data)

# %%
print(f"Length of dataset: {len(train_data)}") 
print(f"Length of dataset: {len(test_data)}") 
print(f"Shape of one sample: {train_data[0][0].shape}, {train_data[0][1].shape}")
fix, ax = plt.subplots(1,2)
ax[0].imshow(train_data[0][0].permute(1,2,0))
ax[1].imshow(train_data[0][1].permute(1,2,0))
# Out:
# Length of dataset: 50000
# Length of dataset: 10000
# Shape of one sample: torch.Size([3, 16, 16]), torch.Size([3, 32, 32])

# %% [markdown]
# ### Prepare dataloader

# %%
# Setup the batch size hyperparameter
BATCH_SIZE = 128

# Turn datasets into iterables (batches)
train_dataloader = DataLoader(train_data, # dataset to turn into iterable
    batch_size=BATCH_SIZE, # how many samples per batch? 
    shuffle=True # shuffle data every epoch?
)

test_dataloader = DataLoader(test_data,
    batch_size=BATCH_SIZE,
    shuffle=False # don't necessarily have to shuffle the testing data
)

# Let's check out what we've created
print(f"Dataloaders: {train_dataloader, test_dataloader}") 
print(f"Length of training dataset: {len(train_dataloader.dataset)}")
print(f"Length of train dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of test dataset: {len(test_dataloader.dataset)}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}")
# Out:
# Dataloaders: (<torch.utils.data.dataloader.DataLoader object at 0x7dd8632f8eb0>, <torch.utils.data.dataloader.DataLoader object at 0x7dd8691a2c50>)
# Length of training dataset: 50000
# Length of train dataloader: 391 batches of 128
# Length of test dataset: 10000
# Length of test dataloader: 79 batches of 128

# %%
batch = next(iter(train_dataloader))
batch[0].shape, batch[1].shape
# Out:
# (torch.Size([128, 3, 16, 16]), torch.Size([128, 3, 32, 32]))

# %% [markdown]
# ### Model Architecture

# %%
class SuperResolutionEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(in_channels=3, 
                      out_channels=64, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(), 
            nn.InstanceNorm2d(64),
            
            nn.Conv2d(in_channels=64, 
                      out_channels=32, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(), 
            nn.InstanceNorm2d(32),

            nn.MaxPool2d(kernel_size = (2,2)),
            
            nn.Conv2d(in_channels=32, 
                      out_channels=32, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),
            nn.InstanceNorm2d(32),
            
            nn.Conv2d(in_channels=32, 
                      out_channels=16, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),
            nn.InstanceNorm2d(16),
            
            nn.MaxPool2d(kernel_size = (2,2)),
            
            nn.Conv2d(in_channels=16, 
                      out_channels=8, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),
            nn.InstanceNorm2d(8),
            
            nn.Conv2d(in_channels=8, 
                      out_channels=8, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),
            nn.InstanceNorm2d(8),
            
            nn.MaxPool2d(kernel_size = (2,2))
            
        )
        
        self.decoder = nn.Sequential(
            nn.Conv2d(in_channels=8,
                      out_channels=8, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),  
            
            nn.Conv2d(in_channels=8,
                      out_channels=8, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),  
            
            nn.UpsamplingBilinear2d(scale_factor = 2),

            nn.Conv2d(in_channels=8,
                      out_channels=16, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),  
            nn.InstanceNorm2d(16),
            
            nn.Conv2d(in_channels=16,
                      out_channels=16, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(), 
            nn.InstanceNorm2d(16),
            
            nn.UpsamplingBilinear2d(scale_factor = 2),

            nn.Conv2d(in_channels=16,
                      out_channels=16, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),  
            nn.InstanceNorm2d(16),
            
            nn.Conv2d(in_channels=16,
                      out_channels=32, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(), 
            nn.InstanceNorm2d(32),
            
            nn.UpsamplingBilinear2d(scale_factor = 2),

            nn.Conv2d(in_channels=32,
                      out_channels=32, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),  
            nn.InstanceNorm2d(32),
            
            nn.Conv2d(in_channels=32,
                      out_channels=64, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),  
            nn.InstanceNorm2d(64),
            
            nn.UpsamplingBilinear2d(scale_factor = 2),
            
            nn.Conv2d(in_channels=64,
                      out_channels=64, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),  
            nn.InstanceNorm2d(64),
            
            nn.Conv2d(in_channels=64,
                      out_channels=32, 
                      kernel_size=(3,3), 
                      padding='same'),
            nn.ReLU(),  
            nn.InstanceNorm2d(32),
            
            nn.Conv2d(in_channels=32,
                      out_channels=3, 
                      kernel_size=(3,3), 
                      padding='same'),
            
        )
    
    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %%
model_1 = SuperResolutionEncoder()
with torch.no_grad():
    print(model_1(batch[0]).shape)
model_1
# Out:
# torch.Size([128, 3, 32, 32])
# SuperResolutionEncoder(
#   (encoder): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (3): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (4): ReLU()
#     (5): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (6): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (8): ReLU()
#     (9): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (10): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (11): ReLU()
#     (12): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (13): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (15): ReLU()
#     (16): InstanceNorm2d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (17): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (18): ReLU()
#     (19): InstanceNorm2d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (20): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (3): ReLU()
#     (4): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#     (5): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (6): ReLU()
#     (7): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (8): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (9): ReLU()
#     (10): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (11): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#     (12): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (13): ReLU()
#     (14): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (15): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (16): ReLU()
#     (17): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (18): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#     (19): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (20): ReLU()
#     (21): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (22): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (23): ReLU()
#     (24): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (25): UpsamplingBilinear2d(scale_factor=2.0, mode='bilinear')
#     (26): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (27): ReLU()
#     (28): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (29): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (30): ReLU()
#     (31): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (32): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   )
# )

# %%
# with torch.no_grad():
#     print(model_1(batch[0])[0] == 0)

# %% [markdown]
# ### Train_model

# %%
# Setup loss function and optimizer
loss_fn = nn.MSELoss()
optimizer = torch.optim.Adam(params=model_1.parameters(), lr=0.01)

# %%
# Setup the num_epochs hyperparameter
NUM_EPOCHS = 50

results = train(model=model_1,
                train_dataloader=train_dataloader,
                test_dataloader=test_dataloader,
                optimizer=optimizer,
                loss_fn=loss_fn,
                epochs=NUM_EPOCHS,
                device=device)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch: 0 | Training_Loss: 0.0699 | Test_Loss: 0.0433 |
# Epoch: 1 | Training_Loss: 0.0368 | Test_Loss: 0.0298 |
# Epoch: 2 | Training_Loss: 0.0305 | Test_Loss: 0.0290 |
# Epoch: 3 | Training_Loss: 0.0288 | Test_Loss: 0.0271 |
# Epoch: 4 | Training_Loss: 0.0283 | Test_Loss: 0.0276 |
# Epoch: 5 | Training_Loss: 0.0267 | Test_Loss: 0.0257 |
# Epoch: 6 | Training_Loss: 0.0258 | Test_Loss: 0.0252 |
# Epoch: 7 | Training_Loss: 0.0256 | Test_Loss: 0.0240 |
# Epoch: 8 | Training_Loss: 0.0250 | Test_Loss: 0.0245 |
# Epoch: 9 | Training_Loss: 0.0251 | Test_Loss: 0.0250 |
# Epoch: 10 | Training_Loss: 0.0247 | Test_Loss: 0.0243 |
# Epoch: 11 | Training_Loss: 0.0243 | Test_Loss: 0.0255 |
# Epoch: 12 | Training_Loss: 0.0238 | Test_Loss: 0.0245 |
# Epoch: 13 | Training_Loss: 0.0232 | Test_Loss: 0.0235 |
# Epoch: 14 | Training_Loss: 0.0232 | Test_Loss: 0.0240 |
# Epoch: 15 | Training_Loss: 0.0231 | Test_Loss: 0.0238 |
# Epoch: 16 | Training_Loss: 0.0230 | Test_Loss: 0.0235 |
# Epoch: 17 | Training_Loss: 0.0230 | Test_Loss: 0.0236 |
# Epoch: 18 | Training_Loss: 0.0227 | Test_Loss: 0.0229 |
# Epoch: 19 | Training_Loss: 0.0228 | Test_Loss: 0.0240 |
# Epoch: 20 | Training_Loss: 0.0228 | Test_Loss: 0.0225 |
# Epoch: 21 | Training_Loss: 0.0226 | Test_Loss: 0.0228 |
# Epoch: 22 | Training_Loss: 0.0224 | Test_Loss: 0.0227 |
# Epoch: 23 | Training_Loss: 0.0224 | Test_Loss: 0.0226 |
# Epoch: 24 | Training_Loss: 0.0224 | Test_Loss: 0.0231 |
# Epoch: 25 | Training_Loss: 0.0224 | Test_Loss: 0.0222 |
# Epoch: 26 | Training_Loss: 0.0222 | Test_Loss: 0.0222 |
# Epoch: 27 | Training_Loss: 0.0222 | Test_Loss: 0.0221 |
# Epoch: 28 | Training_Loss: 0.0220 | Test_Loss: 0.0215 |
# Epoch: 29 | Training_Loss: 0.0216 | Test_Loss: 0.0211 |
# Epoch: 30 | Training_Loss: 0.0211 | Test_Loss: 0.0220 |
# Epoch: 31 | Training_Loss: 0.0210 | Test_Loss: 0.0227 |
# Epoch: 32 | Training_Loss: 0.0209 | Test_Loss: 0.0215 |
# Epoch: 33 | Training_Loss: 0.0207 | Test_Loss: 0.0207 |
# Epoch: 34 | Training_Loss: 0.0206 | Test_Loss: 0.0205 |
# Epoch: 35 | Training_Loss: 0.0206 | Test_Loss: 0.0216 |
# Epoch: 36 | Training_Loss: 0.0205 | Test_Loss: 0.0203 |
# Epoch: 37 | Training_Loss: 0.0204 | Test_Loss: 0.0206 |
# Epoch: 38 | Training_Loss: 0.0203 | Test_Loss: 0.0208 |
# Epoch: 39 | Training_Loss: 0.0203 | Test_Loss: 0.0207 |
# Epoch: 40 | Training_Loss: 0.0202 | Test_Loss: 0.0202 |
# Epoch: 41 | Training_Loss: 0.0290 | Test_Loss: 0.0229 |
# Epoch: 42 | Training_Loss: 0.0214 | Test_Loss: 0.0216 |
# Epoch: 43 | Training_Loss: 0.0206 | Test_Loss: 0.0209 |
# Epoch: 44 | Training_Loss: 0.0205 | Test_Loss: 0.0205 |
# Epoch: 45 | Training_Loss: 0.0204 | Test_Loss: 0.0206 |
# Epoch: 46 | Training_Loss: 0.0203 | Test_Loss: 0.0210 |
# Epoch: 47 | Training_Loss: 0.0203 | Test_Loss: 0.0203 |
# Epoch: 48 | Training_Loss: 0.0203 | Test_Loss: 0.0205 |
# Epoch: 49 | Training_Loss: 0.0202 | Test_Loss: 0.0199 |

# %% [markdown]
# ### Plot training results

# %%
plot_results(results["Training_Loss"], results["Test_Loss"])

# %% [markdown]
# ### Test

# %%
random_indices = torch.randint(0,10_000, size = [7])
random_indices
# Out:
# tensor([6502,  359, 2285, 5960, 8133, 5432,  158])

# %%
fig, ax = plt.subplots(nrows=7, ncols=3, figsize = (10,10))  
fig.set_facecolor('white')


for i in range(7):
    ax[i][0].imshow(test_data[random_indices[i]][0].permute(1,2,0))
    ax[i][0].set_title('Noise data')
    
    ax[i][1].imshow(test_data[random_indices[i]][1].permute(1,2,0))
    ax[i][1].set_title('Noise-free data')
    
    with torch.no_grad():
        prediction = model_1(test_data[random_indices[i]][0].unsqueeze(0).to(device))
    prediction_np = prediction.cpu().numpy().squeeze(0).transpose(1, 2, 0)
    ax[i][2].imshow(prediction_np)
    ax[i][2].set_title('Model_prediction')
    
plt.tight_layout()
